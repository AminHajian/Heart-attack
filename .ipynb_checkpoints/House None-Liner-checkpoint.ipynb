# %% [markdown]
# # House Price whit non-Liner

# %% [markdown]
# ### import :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# ### read DATAs :
# and try to remove null valous and bollshits
# ##### chang type of Area
# from object(str) to float

# %%
data = pd.read_csv("housePrice.csv")
data

# bool_series = pd.notnull(data["Address"])
# data[bool_series]
df = data.dropna()

# befor that Area was str and i chenge this type to float 
pd.to_numeric(df["Area"], downcast='float')
df
# Out:
#         Area  Room Parking Warehouse Elevator      Address         Price  \
# 5     1000.0   2.0    True      True    False     Damavand  7.000000e+09
# 6      929.0   5.0    True      True    False        Zafar  8.000000e+10
# 7      900.0   3.0    True      True    False     Damavand  8.500000e+09
# 8      863.0   2.0    True      True     True   Gheitarieh  7.830000e+09
# 9      750.0   5.0    True      True     True   Mahmoudieh  7.500000e+10
# ...      ...   ...     ...       ...      ...          ...           ...
# 3474    35.0   1.0    True      True    False     Salsabil  7.800000e+08
# 3475    33.0   1.0   False      True    False     Beryanak  5.600000e+08
# 3476    32.0   1.0   False      True    False      Hashemi  6.100000e+08
# 3477    32.0   1.0   False      True     True    Eskandari  9.400000e+08
# 3478    30.0   0.0   False      True    False  Ostad Moein  5.000000e+08
#
#       Price(USD)
# 5      233333.33
# 6     2666666.67
# 7      283333.33
# 8      261000.00
# ...

# %%
x_data, y_data , z_data= (df["Area"].values, df["Price(USD)"].values , df['Room'].values)
plt.plot(x_data, y_data,z_data ,'bo')
plt.ylabel('Price')
plt.xlabel('Area')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14600\2380261124.py in <module>
#       3 plt.ylabel('Price')
#       4 plt.xlabel('Area')
# ----> 5 plt.zlabel('Room')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'

# %% [markdown]
# ## choose the best model

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = 1*(x**3) + 1*(x**2) + 1*x + 3
plt.plot(x,y) 

plt.ylabel('Price')
plt.xlabel('Area')
plt.show()

# %%
def sigmoid(x, Beta_1, Beta_2, Beta_3 , Beta_4):
     y = Beta_1*(x**3) + Beta_2*(x**2) + Beta_3*x + Beta_4
     return y

# %%
beta_1 = 0
beta_2 = 4
Beta_3 = 1
Beta_4 = 1

#logistic function
Y_pred = sigmoid(x_data, beta_1 , beta_2 , Beta_3, Beta_4)

#plot initial prediction against datapoints
plt.plot(x_data, Y_pred)
plt.plot(x_data, y_data, 'ro')

# %% [markdown]
# ## lets find zarayeb

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, x_data, y_data)
#print the final parameters
print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1] ))
# Out:
#  beta_1 = -0.005832, beta_2 = 3.331883

# %%
x = np.linspace(0, 1000, 1001)
plt.figure(figsize=(8,5))

y = sigmoid(x, *popt)
plt.plot(x_data, y_data, 'ro', label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('Price')
plt.xlabel('Area')
plt.show()

# print(sigmoid(1.004468718967229,*popt))
